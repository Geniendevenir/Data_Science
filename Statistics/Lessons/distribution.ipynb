# %% [markdown]
# ### Vocabulary
# Outlier: Extreme values from both end.
# Robust to Outliers
# Sensitive to Outliers
#
# ### Observing Distribution
#
# #### Boxplot
#
# #### Frequency Table
#
# #### Histogram
#
# #### Density plot
#
# ### Exploring Binary & Categorical Data
#
# ### Exploring Two or more Variables
